# %% [markdown]
# <a href="https://colab.research.google.com/github/devanshu6738/Machine-Learning/blob/main/SQLonPANDAdataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pandasql
! pip install duckdb
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pandasql: filename=pandasql-0.7.3-py3-none-any.whl size=26773 sha256=289e835dbcf23802e88cb27a84a243d1e0c29163bdd2b115611cccd3b81ce0ea
#   Stored in directory: /root/.cache/pip/wheels/15/a1/e7/6f92f295b5272ae5c02365e6b8fa19cb93f16a537090a1cf27
# Successfully built pandasql
# ...
